# %%
import torch
import matplotlib.pyplot as plt
from safetensors.torch import load_file
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.manifold import TSNE, MDS
import os
import numpy as np
from matplotlib.colors import ListedColormap
from tqdm import tqdm

# %%
BASE_DIR = "encoding_data"
names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14", "gpt_4.1",
 "claude_3_5_haiku_20241022", "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805", "risky_financial_advice"]

# names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14",  "gpt_4.1", "claude_3_5_haiku_20241022", 
#          "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805", "Qwen_Qwen1.5-MoE-A2.7B", "Qwen_Qwen2.5-1.5B",
#          "meta-llama_Llama-3.2-1B", "meta-llama_Llama-3.2-3B", "risky_financial_advice"]

# names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14", "gpt_4.1",
#  "claude_3_5_haiku_20241022", "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805"]
data = {}
for i, name in enumerate(names):
    data[name] = {'file': f"{BASE_DIR}/{name}_embeddings.npz", "label": i, "batch": 1}

# %%
for key in data.keys():
    d = data[key]
    d["embed"] = np.load(f"{d['file']}")["embeddings"]

# %%
X = []
y = []
b = []
keys = list(data.keys())
for i in range(len(data)):
            x = torch.tensor(data[keys[i]]["embed"])[:3000,:]
            X.append(x)
            y.append(data[keys[i]]["label"]*torch.ones(x.shape[0]))
            b.append(torch.arange(x.shape[0]))
X = torch.cat(X)
y = torch.cat(y)
b = torch.cat(b)

# %%
y

# %%
X_t = X.clone()
for i in tqdm(range(torch.min(b), torch.max(b)+1)):
    indx = torch.where(b==i,1,0)
    X_t[indx,:] -= torch.mean(X[indx,:],dim=0,keepdim=True)

# %% [markdown]
# # Classification

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
# clf = LogisticRegression(random_state=0).fit(X_train, y_train)
clf = make_pipeline(StandardScaler(),
                    LogisticRegression(random_state=0)).fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
r = torch.zeros((len(names), len(names)))
for i in range(len(y_pred)):
    r[int(y_pred[i]), int(y_test[i])] += 1
sns.heatmap(np.log1p(r), xticklabels=names, yticklabels=names)

# %%
y_T

# %% [markdown]
# ## Classifier + Reconstruction

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# ----- Device -----
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)

#----- DataLoader -----
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40, stratify=y)

# Exclude labels 1, 2, 4, 8, 10

# X_T = X_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4) * (y_train != 8) * (y_train != 10))].clone().to(device)
# y_T = y_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4) * (y_train != 8) * (y_train != 10))].clone().to(device)

X_T = X_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4))].clone().to(device)
y_T = y_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4))].clone().to(device)

train_dataset = TensorDataset(X_T, y_T)
train_loader = DataLoader(train_dataset, batch_size=13500, shuffle=True)

# ----- Hyperparameters -----
input_dim = 384
hidden1 = 2000
hidden2 = 1000
z_dim = 8
n_classes = 8
lr = 1e-3#5e-4
epochs = 300
sigma_z = 0.05
sigma_x = 0.1

# ----- Model -----
class SupAutoencoder(nn.Module):
    def __init__(self, input_dim, z_dim, n_classes):
        super().__init__()
        # Encoder
        self.enc = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.SiLU(),
            nn.Linear(hidden1, hidden2),
            nn.SiLU(),
            nn.Linear(hidden2, z_dim)  # z
        )
        self.ln = nn.LayerNorm(z_dim)
        # Decoder
        self.dec = nn.Sequential(
            nn.Linear(z_dim, hidden2),
            nn.SiLU(),
            nn.Linear(hidden2, hidden1),
            nn.SiLU(),
            nn.Linear(hidden1, input_dim)  # x_hat
        )
        # Classifier head on z
        self.cls = nn.Sequential(
            # nn.Linear(z_dim, hidden2),
            # nn.SiLU(),
            # nn.Linear(hidden2, n_classes)
            nn.Linear(z_dim, n_classes)
        )
    def forward(self, x):
        xnoisy = x + sigma_x * torch.randn_like(x) * torch.std(x, dim=0, keepdim=True)
        z = self.enc(xnoisy)
        znoisy = z + sigma_z * torch.randn_like(z) * torch.std(z, dim=0, keepdim=True)
        x_hat = self.dec(znoisy)
        logits = self.cls(z)
        return x_hat, logits, z

class CenterLoss(nn.Module):
    def __init__(self, num_classes, feat_dim):
        super().__init__()
        self.centers = nn.Parameter(torch.randn(num_classes, feat_dim))

    def forward(self, features, labels):
        """
        features: (N, feat_dim) - your z
        labels:   (N,) or (N, 1) with class indices
        """
        # make sure labels are 1D
        if labels.dim() > 1:
            labels = labels.squeeze(-1)
        labels = labels

        # gather the centers for each sample's class
        centers_batch = self.centers[labels]   # (N, feat_dim)

        # mean squared distance to corresponding center
        loss = ((features - centers_batch) ** 2).sum(dim=1).mean()
        return loss

# ----- Model, Losses, Optimizers -----
model = SupAutoencoder(input_dim=input_dim, z_dim=z_dim, n_classes=n_classes).to(device)
opt = torch.optim.Adam(model.parameters(), lr=lr)
ce_loss = nn.CrossEntropyLoss(label_smoothing=0.05)
center_loss = CenterLoss(num_classes=n_classes, feat_dim=z_dim).to(device)
opt_center = torch.optim.SGD(center_loss.parameters(), lr=0.5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
# Out:
# Using device: cuda

# %%
torch.where((y_T == 1))

# %%
logits.shape

# %%
# ----- Training Loop -----
lambda_cls = 1.0
lambda_recon = 100.0
lambda_center = 0. #0.1
for epoch in range(epochs):
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_batch = y_batch.to(device).long()
        x_hat, logits, z = model(X_batch)
        recon = F.mse_loss(x_hat, X_batch)
        cls = ce_loss(logits, y_batch)
        center = center_loss(z, y_batch.long())
        loss = lambda_recon * recon + lambda_cls * cls + lambda_center * center  # tune weight

        opt.zero_grad()
        opt_center.zero_grad()
        loss.backward()
        opt.step()
        opt_center.step()
        scheduler.step()

    print(f"Epoch {epoch+1}/{epochs}  Classification Loss: {(lambda_cls * cls).item():.4f} , Reconstruction Loss: {(lambda_recon * recon).item():.4f} , Center Loss: {(lambda_center * center).item():.4f}")
# Out:
# Epoch 1/300  Classification Loss: 2.3893 , Reconstruction Loss: 0.5859 , Center Loss: 0.0000
# Epoch 2/300  Classification Loss: 2.3406 , Reconstruction Loss: 0.3181 , Center Loss: 0.0000
# Epoch 3/300  Classification Loss: 2.2716 , Reconstruction Loss: 0.3140 , Center Loss: 0.0000
# Epoch 4/300  Classification Loss: 2.1696 , Reconstruction Loss: 0.2872 , Center Loss: 0.0000
# Epoch 5/300  Classification Loss: 2.0433 , Reconstruction Loss: 0.2884 , Center Loss: 0.0000
# Epoch 6/300  Classification Loss: 1.9540 , Reconstruction Loss: 0.3060 , Center Loss: 0.0000
# Epoch 7/300  Classification Loss: 1.9226 , Reconstruction Loss: 0.3154 , Center Loss: 0.0000
# Epoch 8/300  Classification Loss: 1.8611 , Reconstruction Loss: 0.2936 , Center Loss: 0.0000
# Epoch 9/300  Classification Loss: 1.7775 , Reconstruction Loss: 0.2581 , Center Loss: 0.0000
# Epoch 10/300  Classification Loss: 1.7391 , Reconstruction Loss: 0.2463 , Center Loss: 0.0000
# Epoch 11/300  Classification Loss: 1.7327 , Reconstruction Loss: 0.2419 , Center Loss: 0.0000
# Epoch 12/300  Classification Loss: 1.6514 , Reconstruction Loss: 0.2407 , Center Loss: 0.0000
# Epoch 13/300  Classification Loss: 1.5759 , Reconstruction Loss: 0.2468 , Center Loss: 0.0000
# Epoch 14/300  Classification Loss: 1.5200 , Reconstruction Loss: 0.3244 , Center Loss: 0.0000
# Epoch 15/300  Classification Loss: 1.4474 , Reconstruction Loss: 0.3619 , Center Loss: 0.0000
# Epoch 16/300  Classification Loss: 1.4319 , Reconstruction Loss: 0.2728 , Center Loss: 0.0000
# Epoch 17/300  Classification Loss: 1.4167 , Reconstruction Loss: 0.2621 , Center Loss: 0.0000
# Epoch 18/300  Classification Loss: 1.3630 , Reconstruction Loss: 0.2427 , Center Loss: 0.0000
# Epoch 19/300  Classification Loss: 1.3200 , Reconstruction Loss: 0.2490 , Center Loss: 0.0000
# Epoch 20/300  Classification Loss: 1.2752 , Reconstruction Loss: 0.2357 , Center Loss: 0.0000
# Epoch 21/300  Classification Loss: 1.2227 , Reconstruction Loss: 0.2397 , Center Loss: 0.0000
# Epoch 22/300  Classification Loss: 1.1758 , Reconstruction Loss: 0.3604 , Center Loss: 0.0000
# Epoch 23/300  Classification Loss: 1.1446 , Reconstruction Loss: 0.3898 , Center Loss: 0.0000
# Epoch 24/300  Classification Loss: 1.1197 , Reconstruction Loss: 0.3010 , Center Loss: 0.0000
# Epoch 25/300  Classification Loss: 1.0981 , Reconstruction Loss: 0.2666 , Center Loss: 0.0000
# Epoch 26/300  Classification Loss: 1.0783 , Reconstruction Loss: 0.2730 , Center Loss: 0.0000
# Epoch 27/300  Classification Loss: 1.0555 , Reconstruction Loss: 0.2664 , Center Loss: 0.0000
# Epoch 28/300  Classification Loss: 1.0499 , Reconstruction Loss: 0.2850 , Center Loss: 0.0000
# Epoch 29/300  Classification Loss: 1.0169 , Reconstruction Loss: 0.2551 , Center Loss: 0.0000
# Epoch 30/300  Classification Loss: 0.9770 , Reconstruction Loss: 0.2425 , Center Loss: 0.0000
# Epoch 31/300  Classification Loss: 0.9780 , Reconstruction Loss: 0.2366 , Center Loss: 0.0000
# Epoch 32/300  Classification Loss: 0.9654 , Reconstruction Loss: 0.2314 , Center Loss: 0.0000
# Epoch 33/300  Classification Loss: 0.9478 , Reconstruction Loss: 0.2295 , Center Loss: 0.0000
# Epoch 34/300  Classification Loss: 0.9336 , Reconstruction Loss: 0.2414 , Center Loss: 0.0000
# Epoch 35/300  Classification Loss: 0.9192 , Reconstruction Loss: 0.2857 , Center Loss: 0.0000
# Epoch 36/300  Classification Loss: 0.9027 , Reconstruction Loss: 0.2538 , Center Loss: 0.0000
# Epoch 37/300  Classification Loss: 0.9070 , Reconstruction Loss: 0.2429 , Center Loss: 0.0000
# Epoch 38/300  Classification Loss: 0.9061 , Reconstruction Loss: 0.2352 , Center Loss: 0.0000
# Epoch 39/300  Classification Loss: 0.8910 , Reconstruction Loss: 0.2244 , Center Loss: 0.0000
# Epoch 40/300  Classification Loss: 0.9040 , Reconstruction Loss: 0.2188 , Center Loss: 0.0000
# Epoch 41/300  Classification Loss: 0.8706 , Reconstruction Loss: 0.2124 , Center Loss: 0.0000
# Epoch 42/300  Classification Loss: 0.8662 , Reconstruction Loss: 0.2096 , Center Loss: 0.0000
# Epoch 43/300  Classification Loss: 0.8875 , Reconstruction Loss: 0.2073 , Center Loss: 0.0000
# Epoch 44/300  Classification Loss: 0.8647 , Reconstruction Loss: 0.2047 , Center Loss: 0.0000
# Epoch 45/300  Classification Loss: 0.8653 , Reconstruction Loss: 0.2034 , Center Loss: 0.0000
# Epoch 46/300  Classification Loss: 0.8719 , Reconstruction Loss: 0.2023 , Center Loss: 0.0000
# Epoch 47/300  Classification Loss: 0.8642 , Reconstruction Loss: 0.2006 , Center Loss: 0.0000
# Epoch 48/300  Classification Loss: 0.8622 , Reconstruction Loss: 0.2006 , Center Loss: 0.0000
# Epoch 49/300  Classification Loss: 0.8630 , Reconstruction Loss: 0.2020 , Center Loss: 0.0000
# Epoch 50/300  Classification Loss: 0.8397 , Reconstruction Loss: 0.1977 , Center Loss: 0.0000
# Epoch 51/300  Classification Loss: 0.8511 , Reconstruction Loss: 0.1976 , Center Loss: 0.0000
# Epoch 52/300  Classification Loss: 0.8417 , Reconstruction Loss: 0.1967 , Center Loss: 0.0000
# Epoch 53/300  Classification Loss: 0.8324 , Reconstruction Loss: 0.1950 , Center Loss: 0.0000
# Epoch 54/300  Classification Loss: 0.8337 , Reconstruction Loss: 0.1954 , Center Loss: 0.0000
# Epoch 55/300  Classification Loss: 0.8187 , Reconstruction Loss: 0.1957 , Center Loss: 0.0000
# Epoch 56/300  Classification Loss: 0.8177 , Reconstruction Loss: 0.1939 , Center Loss: 0.0000
# Epoch 57/300  Classification Loss: 0.8228 , Reconstruction Loss: 0.1940 , Center Loss: 0.0000
# Epoch 58/300  Classification Loss: 0.8432 , Reconstruction Loss: 0.1944 , Center Loss: 0.0000
# Epoch 59/300  Classification Loss: 0.8346 , Reconstruction Loss: 0.1954 , Center Loss: 0.0000
# Epoch 60/300  Classification Loss: 0.8315 , Reconstruction Loss: 0.1928 , Center Loss: 0.0000
# Epoch 61/300  Classification Loss: 0.8171 , Reconstruction Loss: 0.1929 , Center Loss: 0.0000
# Epoch 62/300  Classification Loss: 0.8274 , Reconstruction Loss: 0.1939 , Center Loss: 0.0000
# Epoch 63/300  Classification Loss: 0.8184 , Reconstruction Loss: 0.1922 , Center Loss: 0.0000
# Epoch 64/300  Classification Loss: 0.8108 , Reconstruction Loss: 0.1914 , Center Loss: 0.0000
# Epoch 65/300  Classification Loss: 0.8173 , Reconstruction Loss: 0.1918 , Center Loss: 0.0000
# Epoch 66/300  Classification Loss: 0.8133 , Reconstruction Loss: 0.1902 , Center Loss: 0.0000
# Epoch 67/300  Classification Loss: 0.8112 , Reconstruction Loss: 0.1905 , Center Loss: 0.0000
# Epoch 68/300  Classification Loss: 0.8126 , Reconstruction Loss: 0.1902 , Center Loss: 0.0000
# Epoch 69/300  Classification Loss: 0.8215 , Reconstruction Loss: 0.1905 , Center Loss: 0.0000
# Epoch 70/300  Classification Loss: 0.8044 , Reconstruction Loss: 0.1897 , Center Loss: 0.0000
# Epoch 71/300  Classification Loss: 0.7994 , Reconstruction Loss: 0.1889 , Center Loss: 0.0000
# Epoch 72/300  Classification Loss: 0.7988 , Reconstruction Loss: 0.1883 , Center Loss: 0.0000
# Epoch 73/300  Classification Loss: 0.8088 , Reconstruction Loss: 0.1891 , Center Loss: 0.0000
# Epoch 74/300  Classification Loss: 0.7977 , Reconstruction Loss: 0.1889 , Center Loss: 0.0000
# Epoch 75/300  Classification Loss: 0.7965 , Reconstruction Loss: 0.1880 , Center Loss: 0.0000
# Epoch 76/300  Classification Loss: 0.8055 , Reconstruction Loss: 0.1872 , Center Loss: 0.0000
# Epoch 77/300  Classification Loss: 0.7801 , Reconstruction Loss: 0.1866 , Center Loss: 0.0000
# Epoch 78/300  Classification Loss: 0.7747 , Reconstruction Loss: 0.1871 , Center Loss: 0.0000
# Epoch 79/300  Classification Loss: 0.7862 , Reconstruction Loss: 0.1870 , Center Loss: 0.0000
# Epoch 80/300  Classification Loss: 0.7829 , Reconstruction Loss: 0.1860 , Center Loss: 0.0000
# Epoch 81/300  Classification Loss: 0.7987 , Reconstruction Loss: 0.1859 , Center Loss: 0.0000
# Epoch 82/300  Classification Loss: 0.8013 , Reconstruction Loss: 0.1865 , Center Loss: 0.0000
# Epoch 83/300  Classification Loss: 0.7825 , Reconstruction Loss: 0.1862 , Center Loss: 0.0000
# Epoch 84/300  Classification Loss: 0.7806 , Reconstruction Loss: 0.1842 , Center Loss: 0.0000
# Epoch 85/300  Classification Loss: 0.7729 , Reconstruction Loss: 0.1845 , Center Loss: 0.0000
# Epoch 86/300  Classification Loss: 0.7773 , Reconstruction Loss: 0.1852 , Center Loss: 0.0000
# Epoch 87/300  Classification Loss: 0.7924 , Reconstruction Loss: 0.1856 , Center Loss: 0.0000
# Epoch 88/300  Classification Loss: 0.7940 , Reconstruction Loss: 0.1851 , Center Loss: 0.0000
# Epoch 89/300  Classification Loss: 0.7873 , Reconstruction Loss: 0.1840 , Center Loss: 0.0000
# Epoch 90/300  Classification Loss: 0.7952 , Reconstruction Loss: 0.1848 , Center Loss: 0.0000
# Epoch 91/300  Classification Loss: 0.7864 , Reconstruction Loss: 0.1858 , Center Loss: 0.0000
# Epoch 92/300  Classification Loss: 0.7710 , Reconstruction Loss: 0.1829 , Center Loss: 0.0000
# Epoch 93/300  Classification Loss: 0.7877 , Reconstruction Loss: 0.1846 , Center Loss: 0.0000
# Epoch 94/300  Classification Loss: 0.7884 , Reconstruction Loss: 0.1846 , Center Loss: 0.0000
# Epoch 95/300  Classification Loss: 0.7729 , Reconstruction Loss: 0.1835 , Center Loss: 0.0000
# Epoch 96/300  Classification Loss: 0.7823 , Reconstruction Loss: 0.1849 , Center Loss: 0.0000
# Epoch 97/300  Classification Loss: 0.7707 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 98/300  Classification Loss: 0.7810 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 99/300  Classification Loss: 0.7845 , Reconstruction Loss: 0.1836 , Center Loss: 0.0000
# Epoch 100/300  Classification Loss: 0.7747 , Reconstruction Loss: 0.1845 , Center Loss: 0.0000
# Epoch 101/300  Classification Loss: 0.7863 , Reconstruction Loss: 0.1838 , Center Loss: 0.0000
# Epoch 102/300  Classification Loss: 0.7836 , Reconstruction Loss: 0.1833 , Center Loss: 0.0000
# Epoch 103/300  Classification Loss: 0.7673 , Reconstruction Loss: 0.1832 , Center Loss: 0.0000
# Epoch 104/300  Classification Loss: 0.7815 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 105/300  Classification Loss: 0.7833 , Reconstruction Loss: 0.1840 , Center Loss: 0.0000
# Epoch 106/300  Classification Loss: 0.7813 , Reconstruction Loss: 0.1827 , Center Loss: 0.0000
# Epoch 107/300  Classification Loss: 0.7778 , Reconstruction Loss: 0.1834 , Center Loss: 0.0000
# Epoch 108/300  Classification Loss: 0.7629 , Reconstruction Loss: 0.1835 , Center Loss: 0.0000
# Epoch 109/300  Classification Loss: 0.7696 , Reconstruction Loss: 0.1834 , Center Loss: 0.0000
# Epoch 110/300  Classification Loss: 0.7793 , Reconstruction Loss: 0.1838 , Center Loss: 0.0000
# Epoch 111/300  Classification Loss: 0.7925 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 112/300  Classification Loss: 0.7779 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 113/300  Classification Loss: 0.7732 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 114/300  Classification Loss: 0.7668 , Reconstruction Loss: 0.1812 , Center Loss: 0.0000
# Epoch 115/300  Classification Loss: 0.7667 , Reconstruction Loss: 0.1825 , Center Loss: 0.0000
# Epoch 116/300  Classification Loss: 0.7809 , Reconstruction Loss: 0.1822 , Center Loss: 0.0000
# Epoch 117/300  Classification Loss: 0.7849 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 118/300  Classification Loss: 0.7596 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 119/300  Classification Loss: 0.7758 , Reconstruction Loss: 0.1824 , Center Loss: 0.0000
# Epoch 120/300  Classification Loss: 0.7589 , Reconstruction Loss: 0.1821 , Center Loss: 0.0000
# Epoch 121/300  Classification Loss: 0.7698 , Reconstruction Loss: 0.1828 , Center Loss: 0.0000
# Epoch 122/300  Classification Loss: 0.7748 , Reconstruction Loss: 0.1827 , Center Loss: 0.0000
# Epoch 123/300  Classification Loss: 0.7810 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 124/300  Classification Loss: 0.7687 , Reconstruction Loss: 0.1815 , Center Loss: 0.0000
# Epoch 125/300  Classification Loss: 0.7610 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 126/300  Classification Loss: 0.7685 , Reconstruction Loss: 0.1831 , Center Loss: 0.0000
# Epoch 127/300  Classification Loss: 0.7783 , Reconstruction Loss: 0.1813 , Center Loss: 0.0000
# Epoch 128/300  Classification Loss: 0.7548 , Reconstruction Loss: 0.1804 , Center Loss: 0.0000
# Epoch 129/300  Classification Loss: 0.7592 , Reconstruction Loss: 0.1815 , Center Loss: 0.0000
# Epoch 130/300  Classification Loss: 0.7726 , Reconstruction Loss: 0.1826 , Center Loss: 0.0000
# Epoch 131/300  Classification Loss: 0.7592 , Reconstruction Loss: 0.1797 , Center Loss: 0.0000
# Epoch 132/300  Classification Loss: 0.7615 , Reconstruction Loss: 0.1825 , Center Loss: 0.0000
# Epoch 133/300  Classification Loss: 0.7602 , Reconstruction Loss: 0.1815 , Center Loss: 0.0000
# Epoch 134/300  Classification Loss: 0.7606 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 135/300  Classification Loss: 0.7802 , Reconstruction Loss: 0.1828 , Center Loss: 0.0000
# Epoch 136/300  Classification Loss: 0.7649 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 137/300  Classification Loss: 0.7609 , Reconstruction Loss: 0.1821 , Center Loss: 0.0000
# Epoch 138/300  Classification Loss: 0.7719 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 139/300  Classification Loss: 0.7465 , Reconstruction Loss: 0.1802 , Center Loss: 0.0000
# Epoch 140/300  Classification Loss: 0.7710 , Reconstruction Loss: 0.1818 , Center Loss: 0.0000
# Epoch 141/300  Classification Loss: 0.7759 , Reconstruction Loss: 0.1818 , Center Loss: 0.0000
# Epoch 142/300  Classification Loss: 0.7669 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 143/300  Classification Loss: 0.7567 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 144/300  Classification Loss: 0.7818 , Reconstruction Loss: 0.1824 , Center Loss: 0.0000
# Epoch 145/300  Classification Loss: 0.7664 , Reconstruction Loss: 0.1804 , Center Loss: 0.0000
# Epoch 146/300  Classification Loss: 0.7555 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 147/300  Classification Loss: 0.7721 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 148/300  Classification Loss: 0.7779 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 149/300  Classification Loss: 0.7623 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 150/300  Classification Loss: 0.7528 , Reconstruction Loss: 0.1800 , Center Loss: 0.0000
# Epoch 151/300  Classification Loss: 0.7759 , Reconstruction Loss: 0.1824 , Center Loss: 0.0000
# Epoch 152/300  Classification Loss: 0.7616 , Reconstruction Loss: 0.1812 , Center Loss: 0.0000
# Epoch 153/300  Classification Loss: 0.7828 , Reconstruction Loss: 0.1823 , Center Loss: 0.0000
# Epoch 154/300  Classification Loss: 0.7783 , Reconstruction Loss: 0.1827 , Center Loss: 0.0000
# Epoch 155/300  Classification Loss: 0.7595 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 156/300  Classification Loss: 0.7743 , Reconstruction Loss: 0.1818 , Center Loss: 0.0000
# Epoch 157/300  Classification Loss: 0.7572 , Reconstruction Loss: 0.1812 , Center Loss: 0.0000
# Epoch 158/300  Classification Loss: 0.7697 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 159/300  Classification Loss: 0.7530 , Reconstruction Loss: 0.1803 , Center Loss: 0.0000
# Epoch 160/300  Classification Loss: 0.7630 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 161/300  Classification Loss: 0.7717 , Reconstruction Loss: 0.1806 , Center Loss: 0.0000
# Epoch 162/300  Classification Loss: 0.7656 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 163/300  Classification Loss: 0.7704 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 164/300  Classification Loss: 0.7749 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 165/300  Classification Loss: 0.7775 , Reconstruction Loss: 0.1813 , Center Loss: 0.0000
# Epoch 166/300  Classification Loss: 0.7779 , Reconstruction Loss: 0.1824 , Center Loss: 0.0000
# Epoch 167/300  Classification Loss: 0.7636 , Reconstruction Loss: 0.1807 , Center Loss: 0.0000
# Epoch 168/300  Classification Loss: 0.7539 , Reconstruction Loss: 0.1821 , Center Loss: 0.0000
# Epoch 169/300  Classification Loss: 0.7840 , Reconstruction Loss: 0.1828 , Center Loss: 0.0000
# Epoch 170/300  Classification Loss: 0.7775 , Reconstruction Loss: 0.1830 , Center Loss: 0.0000
# Epoch 171/300  Classification Loss: 0.7719 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 172/300  Classification Loss: 0.7565 , Reconstruction Loss: 0.1804 , Center Loss: 0.0000
# Epoch 173/300  Classification Loss: 0.7699 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 174/300  Classification Loss: 0.7677 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 175/300  Classification Loss: 0.7594 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 176/300  Classification Loss: 0.7831 , Reconstruction Loss: 0.1831 , Center Loss: 0.0000
# Epoch 177/300  Classification Loss: 0.7599 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 178/300  Classification Loss: 0.7663 , Reconstruction Loss: 0.1800 , Center Loss: 0.0000
# Epoch 179/300  Classification Loss: 0.7681 , Reconstruction Loss: 0.1801 , Center Loss: 0.0000
# Epoch 180/300  Classification Loss: 0.7611 , Reconstruction Loss: 0.1816 , Center Loss: 0.0000
# Epoch 181/300  Classification Loss: 0.7635 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 182/300  Classification Loss: 0.7710 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 183/300  Classification Loss: 0.7578 , Reconstruction Loss: 0.1810 , Center Loss: 0.0000
# Epoch 184/300  Classification Loss: 0.7664 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 185/300  Classification Loss: 0.7791 , Reconstruction Loss: 0.1827 , Center Loss: 0.0000
# Epoch 186/300  Classification Loss: 0.7619 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 187/300  Classification Loss: 0.7608 , Reconstruction Loss: 0.1821 , Center Loss: 0.0000
# Epoch 188/300  Classification Loss: 0.7702 , Reconstruction Loss: 0.1804 , Center Loss: 0.0000
# Epoch 189/300  Classification Loss: 0.7604 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 190/300  Classification Loss: 0.7585 , Reconstruction Loss: 0.1803 , Center Loss: 0.0000
# Epoch 191/300  Classification Loss: 0.7734 , Reconstruction Loss: 0.1818 , Center Loss: 0.0000
# Epoch 192/300  Classification Loss: 0.7784 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 193/300  Classification Loss: 0.7678 , Reconstruction Loss: 0.1824 , Center Loss: 0.0000
# Epoch 194/300  Classification Loss: 0.7679 , Reconstruction Loss: 0.1826 , Center Loss: 0.0000
# Epoch 195/300  Classification Loss: 0.7729 , Reconstruction Loss: 0.1817 , Center Loss: 0.0000
# Epoch 196/300  Classification Loss: 0.7475 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 197/300  Classification Loss: 0.7672 , Reconstruction Loss: 0.1812 , Center Loss: 0.0000
# Epoch 198/300  Classification Loss: 0.7576 , Reconstruction Loss: 0.1811 , Center Loss: 0.0000
# Epoch 199/300  Classification Loss: 0.7615 , Reconstruction Loss: 0.1805 , Center Loss: 0.0000
# Epoch 200/300  Classification Loss: 0.7712 , Reconstruction Loss: 0.1800 , Center Loss: 0.0000
# Epoch 201/300  Classification Loss: 0.7536 , Reconstruction Loss: 0.1807 , Center Loss: 0.0000
# Epoch 202/300  Classification Loss: 0.7664 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 203/300  Classification Loss: 0.7463 , Reconstruction Loss: 0.1816 , Center Loss: 0.0000
# Epoch 204/300  Classification Loss: 0.7615 , Reconstruction Loss: 0.1806 , Center Loss: 0.0000
# Epoch 205/300  Classification Loss: 0.7671 , Reconstruction Loss: 0.1818 , Center Loss: 0.0000
# Epoch 206/300  Classification Loss: 0.7592 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 207/300  Classification Loss: 0.7557 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 208/300  Classification Loss: 0.7539 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 209/300  Classification Loss: 0.7413 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 210/300  Classification Loss: 0.7514 , Reconstruction Loss: 0.1813 , Center Loss: 0.0000
# Epoch 211/300  Classification Loss: 0.7554 , Reconstruction Loss: 0.1816 , Center Loss: 0.0000
# Epoch 212/300  Classification Loss: 0.7494 , Reconstruction Loss: 0.1828 , Center Loss: 0.0000
# Epoch 213/300  Classification Loss: 0.7649 , Reconstruction Loss: 0.1915 , Center Loss: 0.0000
# Epoch 214/300  Classification Loss: 0.7442 , Reconstruction Loss: 0.2126 , Center Loss: 0.0000
# Epoch 215/300  Classification Loss: 0.7553 , Reconstruction Loss: 0.2144 , Center Loss: 0.0000
# Epoch 216/300  Classification Loss: 0.7533 , Reconstruction Loss: 0.2051 , Center Loss: 0.0000
# Epoch 217/300  Classification Loss: 0.7481 , Reconstruction Loss: 0.2165 , Center Loss: 0.0000
# Epoch 218/300  Classification Loss: 0.7509 , Reconstruction Loss: 0.2098 , Center Loss: 0.0000
# Epoch 219/300  Classification Loss: 0.7404 , Reconstruction Loss: 0.2003 , Center Loss: 0.0000
# Epoch 220/300  Classification Loss: 0.7564 , Reconstruction Loss: 0.1918 , Center Loss: 0.0000
# Epoch 221/300  Classification Loss: 0.7613 , Reconstruction Loss: 0.1953 , Center Loss: 0.0000
# Epoch 222/300  Classification Loss: 0.7455 , Reconstruction Loss: 0.1918 , Center Loss: 0.0000
# Epoch 223/300  Classification Loss: 0.7517 , Reconstruction Loss: 0.1909 , Center Loss: 0.0000
# Epoch 224/300  Classification Loss: 0.7460 , Reconstruction Loss: 0.1925 , Center Loss: 0.0000
# Epoch 225/300  Classification Loss: 0.7438 , Reconstruction Loss: 0.2006 , Center Loss: 0.0000
# Epoch 226/300  Classification Loss: 0.7603 , Reconstruction Loss: 0.2306 , Center Loss: 0.0000
# Epoch 227/300  Classification Loss: 0.7364 , Reconstruction Loss: 0.2329 , Center Loss: 0.0000
# Epoch 228/300  Classification Loss: 0.7530 , Reconstruction Loss: 0.2306 , Center Loss: 0.0000
# Epoch 229/300  Classification Loss: 0.7557 , Reconstruction Loss: 0.2089 , Center Loss: 0.0000
# Epoch 230/300  Classification Loss: 0.7402 , Reconstruction Loss: 0.1998 , Center Loss: 0.0000
# Epoch 231/300  Classification Loss: 0.7447 , Reconstruction Loss: 0.1951 , Center Loss: 0.0000
# Epoch 232/300  Classification Loss: 0.7583 , Reconstruction Loss: 0.1943 , Center Loss: 0.0000
# Epoch 233/300  Classification Loss: 0.7513 , Reconstruction Loss: 0.1921 , Center Loss: 0.0000
# Epoch 234/300  Classification Loss: 0.7680 , Reconstruction Loss: 0.1895 , Center Loss: 0.0000
# Epoch 235/300  Classification Loss: 0.7254 , Reconstruction Loss: 0.1915 , Center Loss: 0.0000
# Epoch 236/300  Classification Loss: 0.7303 , Reconstruction Loss: 0.2019 , Center Loss: 0.0000
# Epoch 237/300  Classification Loss: 0.7430 , Reconstruction Loss: 0.2445 , Center Loss: 0.0000
# Epoch 238/300  Classification Loss: 0.7449 , Reconstruction Loss: 0.2298 , Center Loss: 0.0000
# Epoch 239/300  Classification Loss: 0.7509 , Reconstruction Loss: 0.2388 , Center Loss: 0.0000
# Epoch 240/300  Classification Loss: 0.7437 , Reconstruction Loss: 0.2184 , Center Loss: 0.0000
# Epoch 241/300  Classification Loss: 0.7458 , Reconstruction Loss: 0.2042 , Center Loss: 0.0000
# Epoch 242/300  Classification Loss: 0.7535 , Reconstruction Loss: 0.1984 , Center Loss: 0.0000
# Epoch 243/300  Classification Loss: 0.7415 , Reconstruction Loss: 0.1939 , Center Loss: 0.0000
# Epoch 244/300  Classification Loss: 0.7490 , Reconstruction Loss: 0.1910 , Center Loss: 0.0000
# Epoch 245/300  Classification Loss: 0.7366 , Reconstruction Loss: 0.1892 , Center Loss: 0.0000
# Epoch 246/300  Classification Loss: 0.7291 , Reconstruction Loss: 0.1918 , Center Loss: 0.0000
# Epoch 247/300  Classification Loss: 0.7394 , Reconstruction Loss: 0.1987 , Center Loss: 0.0000
# Epoch 248/300  Classification Loss: 0.7330 , Reconstruction Loss: 0.2208 , Center Loss: 0.0000
# Epoch 249/300  Classification Loss: 0.7307 , Reconstruction Loss: 0.2194 , Center Loss: 0.0000
# Epoch 250/300  Classification Loss: 0.7299 , Reconstruction Loss: 0.2314 , Center Loss: 0.0000
# Epoch 251/300  Classification Loss: 0.7487 , Reconstruction Loss: 0.2131 , Center Loss: 0.0000
# Epoch 252/300  Classification Loss: 0.7511 , Reconstruction Loss: 0.2101 , Center Loss: 0.0000
# Epoch 253/300  Classification Loss: 0.7462 , Reconstruction Loss: 0.2001 , Center Loss: 0.0000
# Epoch 254/300  Classification Loss: 0.7318 , Reconstruction Loss: 0.1922 , Center Loss: 0.0000
# Epoch 255/300  Classification Loss: 0.7287 , Reconstruction Loss: 0.1895 , Center Loss: 0.0000
# Epoch 256/300  Classification Loss: 0.7452 , Reconstruction Loss: 0.1906 , Center Loss: 0.0000
# Epoch 257/300  Classification Loss: 0.7301 , Reconstruction Loss: 0.1881 , Center Loss: 0.0000
# Epoch 258/300  Classification Loss: 0.7308 , Reconstruction Loss: 0.1938 , Center Loss: 0.0000
# Epoch 259/300  Classification Loss: 0.7277 , Reconstruction Loss: 0.2025 , Center Loss: 0.0000
# Epoch 260/300  Classification Loss: 0.7464 , Reconstruction Loss: 0.2191 , Center Loss: 0.0000
# Epoch 261/300  Classification Loss: 0.7269 , Reconstruction Loss: 0.2186 , Center Loss: 0.0000
# Epoch 262/300  Classification Loss: 0.7358 , Reconstruction Loss: 0.2099 , Center Loss: 0.0000
# Epoch 263/300  Classification Loss: 0.7330 , Reconstruction Loss: 0.1963 , Center Loss: 0.0000
# Epoch 264/300  Classification Loss: 0.7204 , Reconstruction Loss: 0.1909 , Center Loss: 0.0000
# Epoch 265/300  Classification Loss: 0.7356 , Reconstruction Loss: 0.1872 , Center Loss: 0.0000
# Epoch 266/300  Classification Loss: 0.7280 , Reconstruction Loss: 0.1860 , Center Loss: 0.0000
# Epoch 267/300  Classification Loss: 0.7261 , Reconstruction Loss: 0.1869 , Center Loss: 0.0000
# Epoch 268/300  Classification Loss: 0.7283 , Reconstruction Loss: 0.1870 , Center Loss: 0.0000
# Epoch 269/300  Classification Loss: 0.7180 , Reconstruction Loss: 0.1969 , Center Loss: 0.0000
# Epoch 270/300  Classification Loss: 0.7207 , Reconstruction Loss: 0.2276 , Center Loss: 0.0000
# Epoch 271/300  Classification Loss: 0.7069 , Reconstruction Loss: 0.2124 , Center Loss: 0.0000
# Epoch 272/300  Classification Loss: 0.7408 , Reconstruction Loss: 0.2236 , Center Loss: 0.0000
# Epoch 273/300  Classification Loss: 0.7051 , Reconstruction Loss: 0.1967 , Center Loss: 0.0000
# Epoch 274/300  Classification Loss: 0.7490 , Reconstruction Loss: 0.1951 , Center Loss: 0.0000
# Epoch 275/300  Classification Loss: 0.7315 , Reconstruction Loss: 0.1872 , Center Loss: 0.0000
# Epoch 276/300  Classification Loss: 0.7471 , Reconstruction Loss: 0.1862 , Center Loss: 0.0000
# Epoch 277/300  Classification Loss: 0.7274 , Reconstruction Loss: 0.1861 , Center Loss: 0.0000
# Epoch 278/300  Classification Loss: 0.7247 , Reconstruction Loss: 0.1825 , Center Loss: 0.0000
# Epoch 279/300  Classification Loss: 0.7268 , Reconstruction Loss: 0.1829 , Center Loss: 0.0000
# Epoch 280/300  Classification Loss: 0.7317 , Reconstruction Loss: 0.1841 , Center Loss: 0.0000
# Epoch 281/300  Classification Loss: 0.7265 , Reconstruction Loss: 0.1861 , Center Loss: 0.0000
# Epoch 282/300  Classification Loss: 0.7192 , Reconstruction Loss: 0.1893 , Center Loss: 0.0000
# Epoch 283/300  Classification Loss: 0.7284 , Reconstruction Loss: 0.1869 , Center Loss: 0.0000
# Epoch 284/300  Classification Loss: 0.7146 , Reconstruction Loss: 0.1827 , Center Loss: 0.0000
# Epoch 285/300  Classification Loss: 0.7271 , Reconstruction Loss: 0.1802 , Center Loss: 0.0000
# Epoch 286/300  Classification Loss: 0.7195 , Reconstruction Loss: 0.1803 , Center Loss: 0.0000
# Epoch 287/300  Classification Loss: 0.7310 , Reconstruction Loss: 0.1814 , Center Loss: 0.0000
# Epoch 288/300  Classification Loss: 0.7346 , Reconstruction Loss: 0.1788 , Center Loss: 0.0000
# Epoch 289/300  Classification Loss: 0.7199 , Reconstruction Loss: 0.1792 , Center Loss: 0.0000
# Epoch 290/300  Classification Loss: 0.7150 , Reconstruction Loss: 0.1765 , Center Loss: 0.0000
# Epoch 291/300  Classification Loss: 0.7128 , Reconstruction Loss: 0.1787 , Center Loss: 0.0000
# Epoch 292/300  Classification Loss: 0.7175 , Reconstruction Loss: 0.1809 , Center Loss: 0.0000
# Epoch 293/300  Classification Loss: 0.6921 , Reconstruction Loss: 0.1788 , Center Loss: 0.0000
# Epoch 294/300  Classification Loss: 0.7273 , Reconstruction Loss: 0.1799 , Center Loss: 0.0000
# Epoch 295/300  Classification Loss: 0.7192 , Reconstruction Loss: 0.1819 , Center Loss: 0.0000
# Epoch 296/300  Classification Loss: 0.7155 , Reconstruction Loss: 0.1828 , Center Loss: 0.0000
# Epoch 297/300  Classification Loss: 0.7172 , Reconstruction Loss: 0.1800 , Center Loss: 0.0000
# Epoch 298/300  Classification Loss: 0.7186 , Reconstruction Loss: 0.1791 , Center Loss: 0.0000
# Epoch 299/300  Classification Loss: 0.7054 , Reconstruction Loss: 0.1778 , Center Loss: 0.0000
# Epoch 300/300  Classification Loss: 0.7156 , Reconstruction Loss: 0.1751 , Center Loss: 0.0000

# %%
model.eval()
with torch.no_grad():
    x_hat, logits, z = model(X_test.to("cuda"))
    y_pred = torch.argmax(logits, dim=1)

# for accuracy calculation, look into the in-distribution classes only
y_test_T = y_test[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4) * (y_test != 8) * (y_test != 10))].clone()
y_pred_T = y_pred[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4) * (y_test != 8) * (y_test != 10))].clone()
overall_accuracy = torch.sum(y_pred_T.to("cpu")==y_test_T.to("cpu"))/len(y_pred_T)

print(overall_accuracy*100)

overall_accuracy_unfiltered = torch.sum(y_pred.to("cpu")==y_test.to("cpu"))/len(y_pred)

print(overall_accuracy_unfiltered*100)
# Out:
# tensor(77.2500)
# tensor(45.4412)

# %%
len(y_T)

# %%
r = torch.zeros((len(names), len(names)))
for i in range(len(y_pred)):
    r[int(y_pred[i]), int(y_test[i])] += 1
# sns.heatmap(r, xticklabels=names, yticklabels=names)
sns.heatmap(np.log1p(r), xticklabels=names, yticklabels=names)
plt.ylabel('Predicted Label')
plt.xlabel('True Label')

# %%
from sklearn.cluster import KMeans

pca = PCA(n_components=2)
emb_2d = pca.fit_transform(z.cpu().numpy())

k = 12
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(z.cpu().numpy())

plt.figure(figsize=(6,5))
plt.scatter(emb_2d[:,0], emb_2d[:,1], c=cluster_labels, s=20, cmap="tab10")
plt.title("PCA projection of embeddings colored by KMeans clusters")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()


from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, confusion_matrix
cm = confusion_matrix(y_test, cluster_labels)
print("Confusion matrix:")
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
xticklabels=[f"Cluster {i}" for i in range(cm.shape[1])],
yticklabels=[f"Class {i}" for i in range(cm.shape[0])])
plt.xlabel("Predicted cluster")
plt.ylabel("True class")
plt.title("Confusion Matrix (Class vs Cluster)")
plt.tight_layout()
plt.show()

# %%
y_test

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z[:, 0].cpu(), z[:, 1].cpu(), c=y_test.cpu(), cmap=cmap,alpha=0.5)
# scatter = plt.scatter(X_nn[:, 0], X_nn[:, 1], c=b, cmap='Spectral')
plt.xlabel('Autoencoder Component 1')
plt.ylabel('Autoencoder Component 2')
plt.title('Autoencoder of response embeddings')
cbar = plt.colorbar(scatter, label='Batch Number')
cbar.ax.set_yticklabels(names) 
# plt.legend(handles=scatter.legend_elements()[0], 
#            labels=names)
plt.show()

# %%
pca = PCA(n_components=2)
z_pca = pca.fit_transform(z.cpu())
z_pca = torch.tensor(z_pca)

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_pca[:, 0], z_pca[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
# scatter = plt.scatter(X_nn[:, 0], X_nn[:, 1], c=b, cmap='Spectral')
plt.xlabel('Autoencoder Component 1')
plt.ylabel('Autoencoder Component 2')
plt.title('Autoencoder of response embeddings')
cbar = plt.colorbar(scatter, label='Batch Number')
cbar.ax.set_yticklabels(names) 
# plt.legend(handles=scatter.legend_elements()[0], 
#            labels=names)
plt.show()

# %%
z_tsne = TSNE(n_components=2, random_state=0).fit_transform(z.cpu())

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('TSNE of response embeddings')
plt.colorbar(scatter, label='Batch Number')
plt.show()

# %%
z_mds = MDS(n_components=2).fit_transform(z.cpu())
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_mds[:, 0], z_mds[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('MDS of response embeddings')
plt.colorbar(scatter, label='Batch Number')
plt.show()
