# %%
import torch
import matplotlib.pyplot as plt
from safetensors.torch import load_file
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.manifold import TSNE, MDS
import os
import numpy as np
from matplotlib.colors import ListedColormap
from tqdm import tqdm

# %%
BASE_DIR = "encoding_data"
names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14", "gpt_4.1",
 "claude_3_5_haiku_20241022", "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805", "risky_financial_advice"]

# names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14",  "gpt_4.1", "claude_3_5_haiku_20241022", 
#          "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805", "Qwen_Qwen1.5-MoE-A2.7B", "Qwen_Qwen2.5-1.5B",
#          "meta-llama_Llama-3.2-1B", "meta-llama_Llama-3.2-3B", "risky_financial_advice"]

# names = ["gpt_3.5_turbo_1106", "gpt_3.5_turbo_0125", "gpt_4.1_2025_04_14", "gpt_4.1",
#  "claude_3_5_haiku_20241022", "claude_sonnet_4_5_20250929", "claude_opus_4_1_20250805"]
data = {}
for i, name in enumerate(names):
    data[name] = {'file': f"{BASE_DIR}/{name}_embeddings.npz", "label": i, "batch": 1}

# %%
for key in data.keys():
    d = data[key]
    d["embed"] = np.load(f"{d['file']}")["embeddings"]

# %%
X = []
y = []
b = []
keys = list(data.keys())
for i in range(len(data)):
            x = torch.tensor(data[keys[i]]["embed"])[:3000,:]
            X.append(x)
            y.append(data[keys[i]]["label"]*torch.ones(x.shape[0]))
            b.append(torch.arange(x.shape[0]))
X = torch.cat(X)
y = torch.cat(y)
b = torch.cat(b)

# %%
y

# %%
X_t = X.clone()
for i in tqdm(range(torch.min(b), torch.max(b)+1)):
    indx = torch.where(b==i,1,0)
    X_t[indx,:] -= torch.mean(X[indx,:],dim=0,keepdim=True)

# %% [markdown]
# # Classification

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
# clf = LogisticRegression(random_state=0).fit(X_train, y_train)
clf = make_pipeline(StandardScaler(),
                    LogisticRegression(random_state=0)).fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
r = torch.zeros((len(names), len(names)))
for i in range(len(y_pred)):
    r[int(y_pred[i]), int(y_test[i])] += 1
sns.heatmap(np.log1p(r), xticklabels=names, yticklabels=names)

# %%
y_T

# %% [markdown]
# ## Classifier + Reconstruction

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# ----- Device -----
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)

#----- DataLoader -----
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40, stratify=y)

# Exclude labels 1, 2, 4, 8, 10

# X_T = X_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4) * (y_train != 8) * (y_train != 10))].clone().to(device)
# y_T = y_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4) * (y_train != 8) * (y_train != 10))].clone().to(device)

X_T = X_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4))].clone().to(device)
y_T = y_train[torch.where((y_train != 1) * (y_train != 2) * (y_train != 4))].clone().to(device)

train_dataset = TensorDataset(X_T, y_T)
train_loader = DataLoader(train_dataset, batch_size=13500, shuffle=True)

# ----- Hyperparameters -----
input_dim = 384
hidden1 = 2000
hidden2 = 1000
z_dim = 8
n_classes = 8
lr = 1e-3#5e-4
epochs = 300
sigma_z = 0.05
sigma_x = 0.1

# ----- Model -----
class SupAutoencoder(nn.Module):
    def __init__(self, input_dim, z_dim, n_classes):
        super().__init__()
        # Encoder
        self.enc = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.SiLU(),
            nn.Linear(hidden1, hidden2),
            nn.SiLU(),
            nn.Linear(hidden2, z_dim)  # z
        )
        self.ln = nn.LayerNorm(z_dim)
        # Decoder
        self.dec = nn.Sequential(
            nn.Linear(z_dim, hidden2),
            nn.SiLU(),
            nn.Linear(hidden2, hidden1),
            nn.SiLU(),
            nn.Linear(hidden1, input_dim)  # x_hat
        )
        # Classifier head on z
        self.cls = nn.Sequential(
            # nn.Linear(z_dim, hidden2),
            # nn.SiLU(),
            # nn.Linear(hidden2, n_classes)
            nn.Linear(z_dim, n_classes)
        )
    def forward(self, x):
        xnoisy = x + sigma_x * torch.randn_like(x) * torch.std(x, dim=0, keepdim=True)
        z = self.enc(xnoisy)
        znoisy = z + sigma_z * torch.randn_like(z) * torch.std(z, dim=0, keepdim=True)
        x_hat = self.dec(znoisy)
        logits = self.cls(z)
        return x_hat, logits, z

class CenterLoss(nn.Module):
    def __init__(self, num_classes, feat_dim):
        super().__init__()
        self.centers = nn.Parameter(torch.randn(num_classes, feat_dim))

    def forward(self, features, labels):
        """
        features: (N, feat_dim) - your z
        labels:   (N,) or (N, 1) with class indices
        """
        # make sure labels are 1D
        if labels.dim() > 1:
            labels = labels.squeeze(-1)
        labels = labels

        # gather the centers for each sample's class
        centers_batch = self.centers[labels]   # (N, feat_dim)

        # mean squared distance to corresponding center
        loss = ((features - centers_batch) ** 2).sum(dim=1).mean()
        return loss

# ----- Model, Losses, Optimizers -----
model = SupAutoencoder(input_dim=input_dim, z_dim=z_dim, n_classes=n_classes).to(device)
opt = torch.optim.Adam(model.parameters(), lr=lr)
ce_loss = nn.CrossEntropyLoss(label_smoothing=0.05)
center_loss = CenterLoss(num_classes=n_classes, feat_dim=z_dim).to(device)
opt_center = torch.optim.SGD(center_loss.parameters(), lr=0.5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
# Out:
# Using device: cuda

# %%
torch.where((y_T == 1))

# %%
logits.shape

# %%
# ----- Training Loop -----
lambda_cls = 1.0
lambda_recon = 100.0
lambda_center = 0. #0.1
for epoch in range(epochs):
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_batch = y_batch.to(device).long()
        x_hat, logits, z = model(X_batch)
        recon = F.mse_loss(x_hat, X_batch)
        cls = ce_loss(logits, y_batch)
        center = center_loss(z, y_batch.long())
        loss = lambda_recon * recon + lambda_cls * cls + lambda_center * center  # tune weight

        opt.zero_grad()
        opt_center.zero_grad()
        loss.backward()
        opt.step()
        opt_center.step()
        scheduler.step()

    print(f"Epoch {epoch+1}/{epochs}  Classification Loss: {(lambda_cls * cls).item():.4f} , Reconstruction Loss: {(lambda_recon * recon).item():.4f} , Center Loss: {(lambda_center * center).item():.4f}")
# Out:
# Epoch 1/300  Classification Loss: 2.0311 , Reconstruction Loss: 0.3173 , Center Loss: 0.0000
# Epoch 2/300  Classification Loss: 1.9870 , Reconstruction Loss: 0.5764 , Center Loss: 0.0000
# Epoch 3/300  Classification Loss: 1.9439 , Reconstruction Loss: 0.8058 , Center Loss: 0.0000
# Epoch 4/300  Classification Loss: 1.9131 , Reconstruction Loss: 0.3164 , Center Loss: 0.0000
# Epoch 5/300  Classification Loss: 1.8662 , Reconstruction Loss: 0.4071 , Center Loss: 0.0000
# Epoch 6/300  Classification Loss: 1.8313 , Reconstruction Loss: 0.3220 , Center Loss: 0.0000
# Epoch 7/300  Classification Loss: 1.7876 , Reconstruction Loss: 0.2504 , Center Loss: 0.0000
# Epoch 8/300  Classification Loss: 1.7295 , Reconstruction Loss: 0.3011 , Center Loss: 0.0000
# Epoch 9/300  Classification Loss: 1.6682 , Reconstruction Loss: 0.3153 , Center Loss: 0.0000
# Epoch 10/300  Classification Loss: 1.6086 , Reconstruction Loss: 0.3032 , Center Loss: 0.0000
# Epoch 11/300  Classification Loss: 1.5518 , Reconstruction Loss: 0.2660 , Center Loss: 0.0000
# Epoch 12/300  Classification Loss: 1.4931 , Reconstruction Loss: 0.2947 , Center Loss: 0.0000
# Epoch 13/300  Classification Loss: 1.4391 , Reconstruction Loss: 0.3089 , Center Loss: 0.0000
# Epoch 14/300  Classification Loss: 1.3920 , Reconstruction Loss: 0.2917 , Center Loss: 0.0000
# Epoch 15/300  Classification Loss: 1.3516 , Reconstruction Loss: 0.2884 , Center Loss: 0.0000
# Epoch 16/300  Classification Loss: 1.3170 , Reconstruction Loss: 0.2991 , Center Loss: 0.0000
# Epoch 17/300  Classification Loss: 1.2862 , Reconstruction Loss: 0.3148 , Center Loss: 0.0000
# Epoch 18/300  Classification Loss: 1.2557 , Reconstruction Loss: 0.3382 , Center Loss: 0.0000
# Epoch 19/300  Classification Loss: 1.2294 , Reconstruction Loss: 0.3058 , Center Loss: 0.0000
# Epoch 20/300  Classification Loss: 1.2069 , Reconstruction Loss: 0.2797 , Center Loss: 0.0000
# Epoch 21/300  Classification Loss: 1.1875 , Reconstruction Loss: 0.2679 , Center Loss: 0.0000
# Epoch 22/300  Classification Loss: 1.1660 , Reconstruction Loss: 0.2585 , Center Loss: 0.0000
# Epoch 23/300  Classification Loss: 1.1377 , Reconstruction Loss: 0.2461 , Center Loss: 0.0000
# Epoch 24/300  Classification Loss: 1.1027 , Reconstruction Loss: 0.2503 , Center Loss: 0.0000
# Epoch 25/300  Classification Loss: 1.0659 , Reconstruction Loss: 0.2516 , Center Loss: 0.0000
# Epoch 26/300  Classification Loss: 1.0331 , Reconstruction Loss: 0.2537 , Center Loss: 0.0000
# Epoch 27/300  Classification Loss: 1.0049 , Reconstruction Loss: 0.2669 , Center Loss: 0.0000
# Epoch 28/300  Classification Loss: 0.9806 , Reconstruction Loss: 0.3958 , Center Loss: 0.0000
# Epoch 29/300  Classification Loss: 0.9582 , Reconstruction Loss: 0.6106 , Center Loss: 0.0000
# Epoch 30/300  Classification Loss: 0.9529 , Reconstruction Loss: 0.2846 , Center Loss: 0.0000
# Epoch 31/300  Classification Loss: 0.9558 , Reconstruction Loss: 0.3543 , Center Loss: 0.0000
# Epoch 32/300  Classification Loss: 0.9567 , Reconstruction Loss: 0.2827 , Center Loss: 0.0000
# Epoch 33/300  Classification Loss: 0.9453 , Reconstruction Loss: 0.2535 , Center Loss: 0.0000
# Epoch 34/300  Classification Loss: 0.9255 , Reconstruction Loss: 0.2625 , Center Loss: 0.0000
# Epoch 35/300  Classification Loss: 0.9089 , Reconstruction Loss: 0.2643 , Center Loss: 0.0000
# Epoch 36/300  Classification Loss: 0.8955 , Reconstruction Loss: 0.2455 , Center Loss: 0.0000
# Epoch 37/300  Classification Loss: 0.8835 , Reconstruction Loss: 0.2349 , Center Loss: 0.0000
# Epoch 38/300  Classification Loss: 0.8695 , Reconstruction Loss: 0.2346 , Center Loss: 0.0000
# Epoch 39/300  Classification Loss: 0.8541 , Reconstruction Loss: 0.2360 , Center Loss: 0.0000
# Epoch 40/300  Classification Loss: 0.8411 , Reconstruction Loss: 0.2311 , Center Loss: 0.0000
# Epoch 41/300  Classification Loss: 0.8313 , Reconstruction Loss: 0.2263 , Center Loss: 0.0000
# Epoch 42/300  Classification Loss: 0.8231 , Reconstruction Loss: 0.2247 , Center Loss: 0.0000
# Epoch 43/300  Classification Loss: 0.8123 , Reconstruction Loss: 0.2223 , Center Loss: 0.0000
# Epoch 44/300  Classification Loss: 0.7994 , Reconstruction Loss: 0.2176 , Center Loss: 0.0000
# Epoch 45/300  Classification Loss: 0.7861 , Reconstruction Loss: 0.2163 , Center Loss: 0.0000
# Epoch 46/300  Classification Loss: 0.7756 , Reconstruction Loss: 0.2169 , Center Loss: 0.0000
# Epoch 47/300  Classification Loss: 0.7688 , Reconstruction Loss: 0.2124 , Center Loss: 0.0000
# Epoch 48/300  Classification Loss: 0.7645 , Reconstruction Loss: 0.2109 , Center Loss: 0.0000
# Epoch 49/300  Classification Loss: 0.7577 , Reconstruction Loss: 0.2104 , Center Loss: 0.0000
# Epoch 50/300  Classification Loss: 0.7488 , Reconstruction Loss: 0.2157 , Center Loss: 0.0000
# Epoch 51/300  Classification Loss: 0.7390 , Reconstruction Loss: 0.2484 , Center Loss: 0.0000
# Epoch 52/300  Classification Loss: 0.7320 , Reconstruction Loss: 0.3530 , Center Loss: 0.0000
# Epoch 53/300  Classification Loss: 0.7282 , Reconstruction Loss: 0.4281 , Center Loss: 0.0000
# Epoch 54/300  Classification Loss: 0.7261 , Reconstruction Loss: 0.3045 , Center Loss: 0.0000
# Epoch 55/300  Classification Loss: 0.7224 , Reconstruction Loss: 0.3472 , Center Loss: 0.0000
# Epoch 56/300  Classification Loss: 0.7183 , Reconstruction Loss: 0.2456 , Center Loss: 0.0000
# Epoch 57/300  Classification Loss: 0.7154 , Reconstruction Loss: 0.2830 , Center Loss: 0.0000
# Epoch 58/300  Classification Loss: 0.7162 , Reconstruction Loss: 0.2364 , Center Loss: 0.0000
# Epoch 59/300  Classification Loss: 0.7181 , Reconstruction Loss: 0.2315 , Center Loss: 0.0000
# Epoch 60/300  Classification Loss: 0.7181 , Reconstruction Loss: 0.2385 , Center Loss: 0.0000
# Epoch 61/300  Classification Loss: 0.7160 , Reconstruction Loss: 0.2206 , Center Loss: 0.0000
# Epoch 62/300  Classification Loss: 0.7120 , Reconstruction Loss: 0.2146 , Center Loss: 0.0000
# Epoch 63/300  Classification Loss: 0.7068 , Reconstruction Loss: 0.2193 , Center Loss: 0.0000
# Epoch 64/300  Classification Loss: 0.7024 , Reconstruction Loss: 0.2126 , Center Loss: 0.0000
# Epoch 65/300  Classification Loss: 0.6988 , Reconstruction Loss: 0.2048 , Center Loss: 0.0000
# Epoch 66/300  Classification Loss: 0.6939 , Reconstruction Loss: 0.2069 , Center Loss: 0.0000
# Epoch 67/300  Classification Loss: 0.6889 , Reconstruction Loss: 0.2087 , Center Loss: 0.0000
# Epoch 68/300  Classification Loss: 0.6828 , Reconstruction Loss: 0.2029 , Center Loss: 0.0000
# Epoch 69/300  Classification Loss: 0.6789 , Reconstruction Loss: 0.1976 , Center Loss: 0.0000
# Epoch 70/300  Classification Loss: 0.6751 , Reconstruction Loss: 0.1999 , Center Loss: 0.0000
# Epoch 71/300  Classification Loss: 0.6716 , Reconstruction Loss: 0.2013 , Center Loss: 0.0000
# Epoch 72/300  Classification Loss: 0.6687 , Reconstruction Loss: 0.1973 , Center Loss: 0.0000
# Epoch 73/300  Classification Loss: 0.6656 , Reconstruction Loss: 0.1942 , Center Loss: 0.0000
# Epoch 74/300  Classification Loss: 0.6626 , Reconstruction Loss: 0.1959 , Center Loss: 0.0000
# Epoch 75/300  Classification Loss: 0.6592 , Reconstruction Loss: 0.1945 , Center Loss: 0.0000
# Epoch 76/300  Classification Loss: 0.6582 , Reconstruction Loss: 0.1926 , Center Loss: 0.0000
# Epoch 77/300  Classification Loss: 0.6552 , Reconstruction Loss: 0.1919 , Center Loss: 0.0000
# Epoch 78/300  Classification Loss: 0.6530 , Reconstruction Loss: 0.1918 , Center Loss: 0.0000
# Epoch 79/300  Classification Loss: 0.6514 , Reconstruction Loss: 0.1911 , Center Loss: 0.0000
# Epoch 80/300  Classification Loss: 0.6495 , Reconstruction Loss: 0.1903 , Center Loss: 0.0000
# Epoch 81/300  Classification Loss: 0.6480 , Reconstruction Loss: 0.1921 , Center Loss: 0.0000
# Epoch 82/300  Classification Loss: 0.6454 , Reconstruction Loss: 0.1958 , Center Loss: 0.0000
# Epoch 83/300  Classification Loss: 0.6432 , Reconstruction Loss: 0.2017 , Center Loss: 0.0000
# Epoch 84/300  Classification Loss: 0.6424 , Reconstruction Loss: 0.2043 , Center Loss: 0.0000
# Epoch 85/300  Classification Loss: 0.6407 , Reconstruction Loss: 0.1948 , Center Loss: 0.0000
# Epoch 86/300  Classification Loss: 0.6393 , Reconstruction Loss: 0.1885 , Center Loss: 0.0000
# Epoch 87/300  Classification Loss: 0.6373 , Reconstruction Loss: 0.1912 , Center Loss: 0.0000
# Epoch 88/300  Classification Loss: 0.6358 , Reconstruction Loss: 0.1859 , Center Loss: 0.0000
# Epoch 89/300  Classification Loss: 0.6345 , Reconstruction Loss: 0.1873 , Center Loss: 0.0000
# Epoch 90/300  Classification Loss: 0.6335 , Reconstruction Loss: 0.1835 , Center Loss: 0.0000
# Epoch 91/300  Classification Loss: 0.6319 , Reconstruction Loss: 0.1845 , Center Loss: 0.0000
# Epoch 92/300  Classification Loss: 0.6307 , Reconstruction Loss: 0.1820 , Center Loss: 0.0000
# Epoch 93/300  Classification Loss: 0.6296 , Reconstruction Loss: 0.1826 , Center Loss: 0.0000
# Epoch 94/300  Classification Loss: 0.6281 , Reconstruction Loss: 0.1808 , Center Loss: 0.0000
# Epoch 95/300  Classification Loss: 0.6262 , Reconstruction Loss: 0.1810 , Center Loss: 0.0000
# Epoch 96/300  Classification Loss: 0.6258 , Reconstruction Loss: 0.1793 , Center Loss: 0.0000
# Epoch 97/300  Classification Loss: 0.6242 , Reconstruction Loss: 0.1796 , Center Loss: 0.0000
# Epoch 98/300  Classification Loss: 0.6231 , Reconstruction Loss: 0.1785 , Center Loss: 0.0000
# Epoch 99/300  Classification Loss: 0.6218 , Reconstruction Loss: 0.1779 , Center Loss: 0.0000
# Epoch 100/300  Classification Loss: 0.6206 , Reconstruction Loss: 0.1774 , Center Loss: 0.0000
# Epoch 101/300  Classification Loss: 0.6193 , Reconstruction Loss: 0.1767 , Center Loss: 0.0000
# Epoch 102/300  Classification Loss: 0.6178 , Reconstruction Loss: 0.1764 , Center Loss: 0.0000
# Epoch 103/300  Classification Loss: 0.6169 , Reconstruction Loss: 0.1754 , Center Loss: 0.0000
# Epoch 104/300  Classification Loss: 0.6156 , Reconstruction Loss: 0.1753 , Center Loss: 0.0000
# Epoch 105/300  Classification Loss: 0.6143 , Reconstruction Loss: 0.1746 , Center Loss: 0.0000
# Epoch 106/300  Classification Loss: 0.6131 , Reconstruction Loss: 0.1741 , Center Loss: 0.0000
# Epoch 107/300  Classification Loss: 0.6134 , Reconstruction Loss: 0.1737 , Center Loss: 0.0000
# Epoch 108/300  Classification Loss: 0.6120 , Reconstruction Loss: 0.1731 , Center Loss: 0.0000
# Epoch 109/300  Classification Loss: 0.6099 , Reconstruction Loss: 0.1729 , Center Loss: 0.0000
# Epoch 110/300  Classification Loss: 0.6093 , Reconstruction Loss: 0.1725 , Center Loss: 0.0000
# Epoch 111/300  Classification Loss: 0.6072 , Reconstruction Loss: 0.1723 , Center Loss: 0.0000
# Epoch 112/300  Classification Loss: 0.6082 , Reconstruction Loss: 0.1721 , Center Loss: 0.0000
# Epoch 113/300  Classification Loss: 0.6067 , Reconstruction Loss: 0.1718 , Center Loss: 0.0000
# Epoch 114/300  Classification Loss: 0.6053 , Reconstruction Loss: 0.1716 , Center Loss: 0.0000
# Epoch 115/300  Classification Loss: 0.6047 , Reconstruction Loss: 0.1715 , Center Loss: 0.0000
# Epoch 116/300  Classification Loss: 0.6040 , Reconstruction Loss: 0.1713 , Center Loss: 0.0000
# Epoch 117/300  Classification Loss: 0.6031 , Reconstruction Loss: 0.1710 , Center Loss: 0.0000
# Epoch 118/300  Classification Loss: 0.6019 , Reconstruction Loss: 0.1709 , Center Loss: 0.0000
# Epoch 119/300  Classification Loss: 0.6008 , Reconstruction Loss: 0.1708 , Center Loss: 0.0000
# Epoch 120/300  Classification Loss: 0.6000 , Reconstruction Loss: 0.1706 , Center Loss: 0.0000
# Epoch 121/300  Classification Loss: 0.5988 , Reconstruction Loss: 0.1704 , Center Loss: 0.0000
# Epoch 122/300  Classification Loss: 0.5990 , Reconstruction Loss: 0.1703 , Center Loss: 0.0000
# Epoch 123/300  Classification Loss: 0.5979 , Reconstruction Loss: 0.1702 , Center Loss: 0.0000
# Epoch 124/300  Classification Loss: 0.5970 , Reconstruction Loss: 0.1701 , Center Loss: 0.0000
# Epoch 125/300  Classification Loss: 0.5959 , Reconstruction Loss: 0.1699 , Center Loss: 0.0000
# Epoch 126/300  Classification Loss: 0.5956 , Reconstruction Loss: 0.1699 , Center Loss: 0.0000
# Epoch 127/300  Classification Loss: 0.5940 , Reconstruction Loss: 0.1698 , Center Loss: 0.0000
# Epoch 128/300  Classification Loss: 0.5938 , Reconstruction Loss: 0.1695 , Center Loss: 0.0000
# Epoch 129/300  Classification Loss: 0.5934 , Reconstruction Loss: 0.1696 , Center Loss: 0.0000
# Epoch 130/300  Classification Loss: 0.5927 , Reconstruction Loss: 0.1695 , Center Loss: 0.0000
# Epoch 131/300  Classification Loss: 0.5909 , Reconstruction Loss: 0.1694 , Center Loss: 0.0000
# Epoch 132/300  Classification Loss: 0.5912 , Reconstruction Loss: 0.1693 , Center Loss: 0.0000
# Epoch 133/300  Classification Loss: 0.5897 , Reconstruction Loss: 0.1693 , Center Loss: 0.0000
# Epoch 134/300  Classification Loss: 0.5896 , Reconstruction Loss: 0.1692 , Center Loss: 0.0000
# Epoch 135/300  Classification Loss: 0.5899 , Reconstruction Loss: 0.1691 , Center Loss: 0.0000
# Epoch 136/300  Classification Loss: 0.5879 , Reconstruction Loss: 0.1691 , Center Loss: 0.0000
# Epoch 137/300  Classification Loss: 0.5870 , Reconstruction Loss: 0.1690 , Center Loss: 0.0000
# Epoch 138/300  Classification Loss: 0.5870 , Reconstruction Loss: 0.1690 , Center Loss: 0.0000
# Epoch 139/300  Classification Loss: 0.5865 , Reconstruction Loss: 0.1689 , Center Loss: 0.0000
# Epoch 140/300  Classification Loss: 0.5856 , Reconstruction Loss: 0.1688 , Center Loss: 0.0000
# Epoch 141/300  Classification Loss: 0.5847 , Reconstruction Loss: 0.1688 , Center Loss: 0.0000
# Epoch 142/300  Classification Loss: 0.5839 , Reconstruction Loss: 0.1687 , Center Loss: 0.0000
# Epoch 143/300  Classification Loss: 0.5836 , Reconstruction Loss: 0.1687 , Center Loss: 0.0000
# Epoch 144/300  Classification Loss: 0.5829 , Reconstruction Loss: 0.1686 , Center Loss: 0.0000
# Epoch 145/300  Classification Loss: 0.5820 , Reconstruction Loss: 0.1686 , Center Loss: 0.0000
# Epoch 146/300  Classification Loss: 0.5819 , Reconstruction Loss: 0.1685 , Center Loss: 0.0000
# Epoch 147/300  Classification Loss: 0.5817 , Reconstruction Loss: 0.1685 , Center Loss: 0.0000
# Epoch 148/300  Classification Loss: 0.5799 , Reconstruction Loss: 0.1684 , Center Loss: 0.0000
# Epoch 149/300  Classification Loss: 0.5797 , Reconstruction Loss: 0.1684 , Center Loss: 0.0000
# Epoch 150/300  Classification Loss: 0.5792 , Reconstruction Loss: 0.1684 , Center Loss: 0.0000
# Epoch 151/300  Classification Loss: 0.5790 , Reconstruction Loss: 0.1682 , Center Loss: 0.0000
# Epoch 152/300  Classification Loss: 0.5786 , Reconstruction Loss: 0.1682 , Center Loss: 0.0000
# Epoch 153/300  Classification Loss: 0.5778 , Reconstruction Loss: 0.1682 , Center Loss: 0.0000
# Epoch 154/300  Classification Loss: 0.5777 , Reconstruction Loss: 0.1682 , Center Loss: 0.0000
# Epoch 155/300  Classification Loss: 0.5766 , Reconstruction Loss: 0.1681 , Center Loss: 0.0000
# Epoch 156/300  Classification Loss: 0.5755 , Reconstruction Loss: 0.1681 , Center Loss: 0.0000
# Epoch 157/300  Classification Loss: 0.5759 , Reconstruction Loss: 0.1680 , Center Loss: 0.0000
# Epoch 158/300  Classification Loss: 0.5751 , Reconstruction Loss: 0.1680 , Center Loss: 0.0000
# Epoch 159/300  Classification Loss: 0.5745 , Reconstruction Loss: 0.1680 , Center Loss: 0.0000
# Epoch 160/300  Classification Loss: 0.5741 , Reconstruction Loss: 0.1680 , Center Loss: 0.0000
# Epoch 161/300  Classification Loss: 0.5738 , Reconstruction Loss: 0.1679 , Center Loss: 0.0000
# Epoch 162/300  Classification Loss: 0.5729 , Reconstruction Loss: 0.1678 , Center Loss: 0.0000
# Epoch 163/300  Classification Loss: 0.5730 , Reconstruction Loss: 0.1678 , Center Loss: 0.0000
# Epoch 164/300  Classification Loss: 0.5723 , Reconstruction Loss: 0.1677 , Center Loss: 0.0000
# Epoch 165/300  Classification Loss: 0.5717 , Reconstruction Loss: 0.1677 , Center Loss: 0.0000
# Epoch 166/300  Classification Loss: 0.5716 , Reconstruction Loss: 0.1677 , Center Loss: 0.0000
# Epoch 167/300  Classification Loss: 0.5718 , Reconstruction Loss: 0.1676 , Center Loss: 0.0000
# Epoch 168/300  Classification Loss: 0.5702 , Reconstruction Loss: 0.1675 , Center Loss: 0.0000
# Epoch 169/300  Classification Loss: 0.5695 , Reconstruction Loss: 0.1674 , Center Loss: 0.0000
# Epoch 170/300  Classification Loss: 0.5702 , Reconstruction Loss: 0.1675 , Center Loss: 0.0000
# Epoch 171/300  Classification Loss: 0.5700 , Reconstruction Loss: 0.1674 , Center Loss: 0.0000
# Epoch 172/300  Classification Loss: 0.5689 , Reconstruction Loss: 0.1673 , Center Loss: 0.0000
# Epoch 173/300  Classification Loss: 0.5685 , Reconstruction Loss: 0.1673 , Center Loss: 0.0000
# Epoch 174/300  Classification Loss: 0.5678 , Reconstruction Loss: 0.1673 , Center Loss: 0.0000
# Epoch 175/300  Classification Loss: 0.5679 , Reconstruction Loss: 0.1671 , Center Loss: 0.0000
# Epoch 176/300  Classification Loss: 0.5677 , Reconstruction Loss: 0.1671 , Center Loss: 0.0000
# Epoch 177/300  Classification Loss: 0.5670 , Reconstruction Loss: 0.1671 , Center Loss: 0.0000
# Epoch 178/300  Classification Loss: 0.5669 , Reconstruction Loss: 0.1671 , Center Loss: 0.0000
# Epoch 179/300  Classification Loss: 0.5671 , Reconstruction Loss: 0.1670 , Center Loss: 0.0000
# Epoch 180/300  Classification Loss: 0.5662 , Reconstruction Loss: 0.1669 , Center Loss: 0.0000
# Epoch 181/300  Classification Loss: 0.5665 , Reconstruction Loss: 0.1669 , Center Loss: 0.0000
# Epoch 182/300  Classification Loss: 0.5650 , Reconstruction Loss: 0.1668 , Center Loss: 0.0000
# Epoch 183/300  Classification Loss: 0.5647 , Reconstruction Loss: 0.1668 , Center Loss: 0.0000
# Epoch 184/300  Classification Loss: 0.5644 , Reconstruction Loss: 0.1668 , Center Loss: 0.0000
# Epoch 185/300  Classification Loss: 0.5645 , Reconstruction Loss: 0.1667 , Center Loss: 0.0000
# Epoch 186/300  Classification Loss: 0.5638 , Reconstruction Loss: 0.1666 , Center Loss: 0.0000
# Epoch 187/300  Classification Loss: 0.5641 , Reconstruction Loss: 0.1666 , Center Loss: 0.0000
# Epoch 188/300  Classification Loss: 0.5632 , Reconstruction Loss: 0.1665 , Center Loss: 0.0000
# Epoch 189/300  Classification Loss: 0.5624 , Reconstruction Loss: 0.1665 , Center Loss: 0.0000
# Epoch 190/300  Classification Loss: 0.5625 , Reconstruction Loss: 0.1665 , Center Loss: 0.0000
# Epoch 191/300  Classification Loss: 0.5624 , Reconstruction Loss: 0.1663 , Center Loss: 0.0000
# Epoch 192/300  Classification Loss: 0.5622 , Reconstruction Loss: 0.1663 , Center Loss: 0.0000
# Epoch 193/300  Classification Loss: 0.5618 , Reconstruction Loss: 0.1662 , Center Loss: 0.0000
# Epoch 194/300  Classification Loss: 0.5620 , Reconstruction Loss: 0.1662 , Center Loss: 0.0000
# Epoch 195/300  Classification Loss: 0.5609 , Reconstruction Loss: 0.1661 , Center Loss: 0.0000
# Epoch 196/300  Classification Loss: 0.5617 , Reconstruction Loss: 0.1660 , Center Loss: 0.0000
# Epoch 197/300  Classification Loss: 0.5610 , Reconstruction Loss: 0.1659 , Center Loss: 0.0000
# Epoch 198/300  Classification Loss: 0.5613 , Reconstruction Loss: 0.1659 , Center Loss: 0.0000
# Epoch 199/300  Classification Loss: 0.5612 , Reconstruction Loss: 0.1658 , Center Loss: 0.0000
# Epoch 200/300  Classification Loss: 0.5617 , Reconstruction Loss: 0.1658 , Center Loss: 0.0000
# Epoch 201/300  Classification Loss: 0.5600 , Reconstruction Loss: 0.1658 , Center Loss: 0.0000
# Epoch 202/300  Classification Loss: 0.5614 , Reconstruction Loss: 0.1657 , Center Loss: 0.0000
# Epoch 203/300  Classification Loss: 0.5593 , Reconstruction Loss: 0.1657 , Center Loss: 0.0000
# Epoch 204/300  Classification Loss: 0.5594 , Reconstruction Loss: 0.1656 , Center Loss: 0.0000
# Epoch 205/300  Classification Loss: 0.5600 , Reconstruction Loss: 0.1655 , Center Loss: 0.0000
# Epoch 206/300  Classification Loss: 0.5593 , Reconstruction Loss: 0.1655 , Center Loss: 0.0000
# Epoch 207/300  Classification Loss: 0.5584 , Reconstruction Loss: 0.1654 , Center Loss: 0.0000
# Epoch 208/300  Classification Loss: 0.5582 , Reconstruction Loss: 0.1654 , Center Loss: 0.0000
# Epoch 209/300  Classification Loss: 0.5582 , Reconstruction Loss: 0.1654 , Center Loss: 0.0000
# Epoch 210/300  Classification Loss: 0.5592 , Reconstruction Loss: 0.1652 , Center Loss: 0.0000
# Epoch 211/300  Classification Loss: 0.5583 , Reconstruction Loss: 0.1652 , Center Loss: 0.0000
# Epoch 212/300  Classification Loss: 0.5586 , Reconstruction Loss: 0.1652 , Center Loss: 0.0000
# Epoch 213/300  Classification Loss: 0.5575 , Reconstruction Loss: 0.1651 , Center Loss: 0.0000
# Epoch 214/300  Classification Loss: 0.5573 , Reconstruction Loss: 0.1651 , Center Loss: 0.0000
# Epoch 215/300  Classification Loss: 0.5581 , Reconstruction Loss: 0.1651 , Center Loss: 0.0000
# Epoch 216/300  Classification Loss: 0.5576 , Reconstruction Loss: 0.1650 , Center Loss: 0.0000
# Epoch 217/300  Classification Loss: 0.5577 , Reconstruction Loss: 0.1650 , Center Loss: 0.0000
# Epoch 218/300  Classification Loss: 0.5577 , Reconstruction Loss: 0.1650 , Center Loss: 0.0000
# Epoch 219/300  Classification Loss: 0.5570 , Reconstruction Loss: 0.1648 , Center Loss: 0.0000
# Epoch 220/300  Classification Loss: 0.5573 , Reconstruction Loss: 0.1648 , Center Loss: 0.0000
# Epoch 221/300  Classification Loss: 0.5574 , Reconstruction Loss: 0.1648 , Center Loss: 0.0000
# Epoch 222/300  Classification Loss: 0.5572 , Reconstruction Loss: 0.1648 , Center Loss: 0.0000
# Epoch 223/300  Classification Loss: 0.5566 , Reconstruction Loss: 0.1647 , Center Loss: 0.0000
# Epoch 224/300  Classification Loss: 0.5567 , Reconstruction Loss: 0.1646 , Center Loss: 0.0000
# Epoch 225/300  Classification Loss: 0.5549 , Reconstruction Loss: 0.1646 , Center Loss: 0.0000
# Epoch 226/300  Classification Loss: 0.5566 , Reconstruction Loss: 0.1647 , Center Loss: 0.0000
# Epoch 227/300  Classification Loss: 0.5557 , Reconstruction Loss: 0.1646 , Center Loss: 0.0000
# Epoch 228/300  Classification Loss: 0.5553 , Reconstruction Loss: 0.1645 , Center Loss: 0.0000
# Epoch 229/300  Classification Loss: 0.5554 , Reconstruction Loss: 0.1645 , Center Loss: 0.0000
# Epoch 230/300  Classification Loss: 0.5555 , Reconstruction Loss: 0.1645 , Center Loss: 0.0000
# Epoch 231/300  Classification Loss: 0.5563 , Reconstruction Loss: 0.1644 , Center Loss: 0.0000
# Epoch 232/300  Classification Loss: 0.5559 , Reconstruction Loss: 0.1644 , Center Loss: 0.0000
# Epoch 233/300  Classification Loss: 0.5550 , Reconstruction Loss: 0.1644 , Center Loss: 0.0000
# Epoch 234/300  Classification Loss: 0.5557 , Reconstruction Loss: 0.1643 , Center Loss: 0.0000
# Epoch 235/300  Classification Loss: 0.5557 , Reconstruction Loss: 0.1643 , Center Loss: 0.0000
# Epoch 236/300  Classification Loss: 0.5557 , Reconstruction Loss: 0.1642 , Center Loss: 0.0000
# Epoch 237/300  Classification Loss: 0.5556 , Reconstruction Loss: 0.1643 , Center Loss: 0.0000
# Epoch 238/300  Classification Loss: 0.5549 , Reconstruction Loss: 0.1642 , Center Loss: 0.0000
# Epoch 239/300  Classification Loss: 0.5552 , Reconstruction Loss: 0.1643 , Center Loss: 0.0000
# Epoch 240/300  Classification Loss: 0.5547 , Reconstruction Loss: 0.1642 , Center Loss: 0.0000
# Epoch 241/300  Classification Loss: 0.5550 , Reconstruction Loss: 0.1642 , Center Loss: 0.0000
# Epoch 242/300  Classification Loss: 0.5549 , Reconstruction Loss: 0.1641 , Center Loss: 0.0000
# Epoch 243/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1641 , Center Loss: 0.0000
# Epoch 244/300  Classification Loss: 0.5538 , Reconstruction Loss: 0.1641 , Center Loss: 0.0000
# Epoch 245/300  Classification Loss: 0.5548 , Reconstruction Loss: 0.1641 , Center Loss: 0.0000
# Epoch 246/300  Classification Loss: 0.5545 , Reconstruction Loss: 0.1641 , Center Loss: 0.0000
# Epoch 247/300  Classification Loss: 0.5553 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 248/300  Classification Loss: 0.5544 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 249/300  Classification Loss: 0.5547 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 250/300  Classification Loss: 0.5535 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 251/300  Classification Loss: 0.5541 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 252/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 253/300  Classification Loss: 0.5537 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 254/300  Classification Loss: 0.5545 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 255/300  Classification Loss: 0.5543 , Reconstruction Loss: 0.1640 , Center Loss: 0.0000
# Epoch 256/300  Classification Loss: 0.5549 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 257/300  Classification Loss: 0.5539 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 258/300  Classification Loss: 0.5532 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 259/300  Classification Loss: 0.5537 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 260/300  Classification Loss: 0.5534 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 261/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 262/300  Classification Loss: 0.5536 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 263/300  Classification Loss: 0.5540 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 264/300  Classification Loss: 0.5524 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 265/300  Classification Loss: 0.5523 , Reconstruction Loss: 0.1639 , Center Loss: 0.0000
# Epoch 266/300  Classification Loss: 0.5539 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 267/300  Classification Loss: 0.5539 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 268/300  Classification Loss: 0.5536 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 269/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 270/300  Classification Loss: 0.5526 , Reconstruction Loss: 0.1638 , Center Loss: 0.0000
# Epoch 271/300  Classification Loss: 0.5532 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 272/300  Classification Loss: 0.5534 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 273/300  Classification Loss: 0.5538 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 274/300  Classification Loss: 0.5531 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 275/300  Classification Loss: 0.5528 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 276/300  Classification Loss: 0.5528 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 277/300  Classification Loss: 0.5524 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 278/300  Classification Loss: 0.5518 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 279/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 280/300  Classification Loss: 0.5540 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 281/300  Classification Loss: 0.5531 , Reconstruction Loss: 0.1636 , Center Loss: 0.0000
# Epoch 282/300  Classification Loss: 0.5530 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 283/300  Classification Loss: 0.5534 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 284/300  Classification Loss: 0.5529 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 285/300  Classification Loss: 0.5517 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 286/300  Classification Loss: 0.5525 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 287/300  Classification Loss: 0.5539 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 288/300  Classification Loss: 0.5542 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 289/300  Classification Loss: 0.5533 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 290/300  Classification Loss: 0.5521 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 291/300  Classification Loss: 0.5525 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 292/300  Classification Loss: 0.5534 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 293/300  Classification Loss: 0.5528 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 294/300  Classification Loss: 0.5545 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 295/300  Classification Loss: 0.5525 , Reconstruction Loss: 0.1636 , Center Loss: 0.0000
# Epoch 296/300  Classification Loss: 0.5535 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 297/300  Classification Loss: 0.5536 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 298/300  Classification Loss: 0.5540 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 299/300  Classification Loss: 0.5532 , Reconstruction Loss: 0.1637 , Center Loss: 0.0000
# Epoch 300/300  Classification Loss: 0.5520 , Reconstruction Loss: 0.1636 , Center Loss: 0.0000

# %%
model.eval()
with torch.no_grad():
    x_hat, logits, z = model(X_test.to("cuda"))
    y_pred = torch.argmax(logits, dim=1)

# for accuracy calculation, look into the in-distribution classes only
# y_test_T = y_test[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4) * (y_test != 8) * (y_test != 10))].clone()
# y_pred_T = y_pred[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4) * (y_test != 8) * (y_test != 10))].clone()

y_test_T = y_test[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4))].clone()
y_pred_T = y_pred[torch.where((y_test != 1) * (y_test != 2) * (y_test != 4))].clone()

overall_accuracy = torch.sum(y_pred_T.to("cpu")==y_test_T.to("cpu"))/len(y_pred_T)

print(overall_accuracy*100)

overall_accuracy_unfiltered = torch.sum(y_pred.to("cpu")==y_test.to("cpu"))/len(y_pred)

print(overall_accuracy_unfiltered*100)
# Out:
# tensor(84.1333)
# tensor(52.5833)

# %%
len(y_T)

# %%
r = torch.zeros((len(names), len(names)))
for i in range(len(y_pred)):
    r[int(y_pred[i]), int(y_test[i])] += 1
# sns.heatmap(r, xticklabels=names, yticklabels=names)
sns.heatmap(np.log1p(r), xticklabels=names, yticklabels=names)
plt.ylabel('Predicted Label')
plt.xlabel('True Label')

# %%
from sklearn.cluster import KMeans

pca = PCA(n_components=2)
emb_2d = pca.fit_transform(z.cpu().numpy())

k = 12
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(z.cpu().numpy())

plt.figure(figsize=(6,5))
plt.scatter(emb_2d[:,0], emb_2d[:,1], c=cluster_labels, s=20, cmap="tab10")
plt.title("PCA projection of embeddings colored by KMeans clusters")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()


from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, confusion_matrix
cm = confusion_matrix(y_test, cluster_labels)
print("Confusion matrix:")
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
xticklabels=[f"Cluster {i}" for i in range(cm.shape[1])],
yticklabels=[f"Class {i}" for i in range(cm.shape[0])])
plt.xlabel("Predicted cluster")
plt.ylabel("True class")
plt.title("Confusion Matrix (Class vs Cluster)")
plt.tight_layout()
plt.show()

# %%
y_test

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z[:, 0].cpu(), z[:, 1].cpu(), c=y_test.cpu(), cmap=cmap,alpha=0.5)
# scatter = plt.scatter(X_nn[:, 0], X_nn[:, 1], c=b, cmap='Spectral')
plt.xlabel('Autoencoder Component 1')
plt.ylabel('Autoencoder Component 2')
plt.title('Autoencoder of response embeddings')
cbar = plt.colorbar(scatter, label='Batch Number')
cbar.ax.set_yticklabels(names) 
# plt.legend(handles=scatter.legend_elements()[0], 
#            labels=names)
plt.show()

# %%
pca = PCA(n_components=2)
z_pca = pca.fit_transform(z.cpu())
z_pca = torch.tensor(z_pca)

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_pca[:, 0], z_pca[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
# scatter = plt.scatter(X_nn[:, 0], X_nn[:, 1], c=b, cmap='Spectral')
plt.xlabel('Autoencoder Component 1')
plt.ylabel('Autoencoder Component 2')
plt.title('Autoencoder of response embeddings')
cbar = plt.colorbar(scatter, label='Batch Number')
cbar.ax.set_yticklabels(names) 
# plt.legend(handles=scatter.legend_elements()[0], 
#            labels=names)
plt.show()

# %%
z_tsne = TSNE(n_components=2, random_state=0).fit_transform(z.cpu())

# %%
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('TSNE of response embeddings')
plt.colorbar(scatter, label='Batch Number')
plt.show()

# %%
z_mds = MDS(n_components=2).fit_transform(z.cpu())
cmap = ListedColormap(sns.color_palette("tab10")[:len(names)])
scatter = plt.scatter(z_mds[:, 0], z_mds[:, 1], c=y_test.cpu(), cmap=cmap,alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('MDS of response embeddings')
plt.colorbar(scatter, label='Batch Number')
plt.show()
